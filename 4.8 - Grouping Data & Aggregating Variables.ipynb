# %% [markdown]
# # THE TASK

# %% [markdown]
# ## ITEM 1

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### DEFINING A SHORT PROJECT FOLDER

# %%
path = r'/Users/cleberjulianoferrareze/Documents/CareerFoundry/Achievement 4/Task 4.7/2021-10 - 4.7 Instacart Grocery Basket'

# %%
path
# Out:
# '/Users/cleberjulianoferrareze/Documents/CareerFoundry/Achievement 4/Task 4.7/2021-10 - 4.7 Instacart Grocery Basket'

# %% [markdown]
# ### IMPORTING DATASET

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_DNV.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (30356128, 19)

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138    prior            28          6                 11
# 1   1977647      138    prior            30          6                 17
# 2    389851      709    prior             2          0                 21
# 3   1813452      764    prior             3          4                 17
# 4   1701441      777    prior            16          1                  7
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %% [markdown]
# ## ITEM 2, 3

# %% [markdown]
# ### AGGREGATING DATA WITH AGG()

# %%
# Performing multiple aggregations

df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                16.559161   2  99
# 2                18.413176   2  99
# 3                18.289622   2  99
# 4                18.915890   2  99
# 5                16.495614   2  99
# 6                17.609390   2  99
# 7                18.303969   2  99
# 8                16.383069   2  99
# 9                17.022963   2  99
# 10               21.227447   2  99
# 11               17.311920   2  99
# 12               16.953554   2  99
# 13               17.727257   2  99
# 14               17.882409   2  99
# 15               17.290123   2  99
# 16               18.755432   2  99
# 17               16.808683   2  99
# 18               20.336389   2  99
# 19               18.258620   2  99
# 20               17.578959   2  99
# 21               23.644477   2  99

# %%
# For the 21 departments, there is no significat difference between min and max values. 
# Also, there is no relevant differences in the mean value, only departments 10 and 21 presents a small one.

# %% [markdown]
# ## ITEM 4

# %% [markdown]
# ### AGGREGATING DATA WITH TRANSFORM()

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.shape
# Out:
# (30356128, 20)

# %%
df_ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %% [markdown]
# ### DERIVING COLUMNS WITH LOC()

# %%
# Creating a loyalty flag for existing customers

df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15095208
# Loyal customer      10104845
# New customer         5156075
# Name: loyalty_flag, dtype: int64

# %%
df_ords_prods_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# ..         ...                         ...       ...            ...     ...
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
# ...

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             3
# 4       777  Regular customer            16
# 5       825      New customer             3
# 6       910  Regular customer            12
# 7      1052  Regular customer            10
# 8      1052  Regular customer            15
# 9      1480    Loyal customer            36
# 10     1480    Loyal customer            38
# 11     1480    Loyal customer            39
# 12     1494  Regular customer             6
# 13     1494  Regular customer             7
# 14     1494  Regular customer             9
# 15     1540  Regular customer             4
# 16     1540  Regular customer             5
# 17     1540  Regular customer             6
# 18     1540  Regular customer             7
# 19     1540  Regular customer             8
# ...

# %% [markdown]
# ## ITEM 5

# %%
# Checking spending habits of the three types of loyalty customers 

df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.404557  1.0  99999.0
# New customer      13.395978  1.0  99999.0
# Regular customer  12.547284  1.0  99999.0

# %%
# The highest mean prices are spent by the new customers, and the lowest ones are spent by loyal cusomters.

# %% [markdown]
# ## ITEM 6

# %%
# Identifying types of spenders

# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

df_ords_prods_merge['spenders'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
df_ords_prods_merge.loc[df_ords_prods_merge['spenders'] < 10, 'spenders_flag'] = 'Low spender'
df_ords_prods_merge.loc[df_ords_prods_merge['spenders'] >= 10, 'spenders_flag'] = 'High spender'

# %%
df_ords_prods_merge[['user_id', 'spenders', 'prices', 'spenders_flag']].head()
# Out:
#    user_id  spenders  prices spenders_flag
# 0      138  6.769286     5.8   Low spender
# 1      138  6.769286     5.8   Low spender
# 2      709  8.071613     5.8   Low spender
# 3      764  4.864103     5.8   Low spender
# 4      777  6.906422     5.8   Low spender

# %% [markdown]
# ## ITEM 7

# %%
# Identifying frequent versus non-frequent customers

# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

df_ords_prods_merge['customer_frequency'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
df_ords_prods_merge.loc[df_ords_prods_merge['customer_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['customer_frequency'] >10) & (df_ords_prods_merge['customer_frequency'] <= 20), 'frequency_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
df_ords_prods_merge[['user_id', 'customer_frequency', 'days_since_prior_order', 'frequency_flag']].head(15)
# Out:
#     user_id  customer_frequency  days_since_prior_order     frequency_flag
# 0       138                 8.0                     3.0  Frequent customer
# 1       138                 8.0                    20.0  Frequent customer
# 2       709                 8.0                     6.0  Frequent customer
# 3       764                 9.0                     9.0  Frequent customer
# 4       777                11.0                    26.0   Regular customer
# 5       825                20.0                    30.0   Regular customer
# 6       910                 6.0                    30.0  Frequent customer
# 7      1052                10.0                    19.0  Frequent customer
# 8      1052                10.0                    15.0  Frequent customer
# 9      1480                 7.0                     7.0  Frequent customer
# 10     1480                 7.0                     7.0  Frequent customer
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (30356128, 25)

# %%
df_ords_prods_merge.head(15)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# ...

# %% [markdown]
# ## ITEM 8, 9, 10

# %%
# Path to export dataset with new fields.

path = r'/Users/cleberjulianoferrareze/Documents/CareerFoundry/Achievement 4/Task 4.8/2021-10 - 4.8 Instacart Grocery Basket'

# %%
path
# Out:
# '/Users/cleberjulianoferrareze/Documents/CareerFoundry/Achievement 4/Task 4.8/2021-10 - 4.8 Instacart Grocery Basket'

# %%
# Export dataset with new columns 

df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_4.8.pkl'))
